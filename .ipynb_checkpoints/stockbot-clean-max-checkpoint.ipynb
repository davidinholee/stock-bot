# %%
import pandas_datareader.data as web
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from keras import models, layers, optimizers
import math

# %%
start = datetime.today() - timedelta(370*5)
end = datetime.today() - timedelta(1)
df = web.DataReader('F', 'iex', start, end)

stock = df.loc[:,'open']
num = len(stock[10:-1])
stock_full = stock
stock = stock[10:-1]
print(num)

#x = np.arange(num)/num
#x = x.reshape(-1, 1)
#y = stock

scaler = MinMaxScaler()
y = np.array(stock).reshape(len(stock), 1)

scaler = scaler.fit(y)
y = scaler.transform(y)
y = y.reshape(len(stock))

# create x: [[10 prices]...[10 prices]]
x = [[None]]*num
for i in range(num):
    x[i] = np.array(stock_full[i:i+10]).reshape(10,1)
    x[i] = scaler.transform(x[i])
    x[i] = x[i].reshape(10)
#x = np.transpose(np.array(x))
x = np.array(x)

#shuffle_indices = np.random.permutation(np.arange(len(y)))
#y = y[shuffle_indices]
#x = x[shuffle_indices]

print(len(x))
print(type(x))
print(x, y)

#print(x.shape, y.shape)

network = models.Sequential()
network.add(layers.Dense(256, activation='relu', input_shape=(10,)))
network.add(layers.Dense(256, activation='relu'))
network.add(layers.Dense(128, activation='relu'))
network.add(layers.Dense(128, activation='relu'))
network.add(layers.Dense(64, activation='relu'))
network.add(layers.Dense(64, activation='relu'))
network.add(layers.Dense(32, activation='relu'))
network.add(layers.Dense(32, activation='relu'))
network.add(layers.Dense(16, activation='relu'))
network.add(layers.Dense(16, activation='relu'))
network.add(layers.Dense(1))
# Out:
# 1247
# 1247
# <class 'numpy.ndarray'>
# [[0.88838788 0.88288862 0.89802486 ... 0.90637101 0.86069705 0.85376549]
#  [0.88288862 0.89802486 0.94620975 ... 0.86069705 0.85376549 0.81638463]
#  [0.89802486 0.94620975 0.92281577 ... 0.85376549 0.81638463 0.80531537]
#  ...
#  [0.0972539  0.13438721 0.10609517 ... 0.09902216 0.04951108 0.02652379]
#  [0.13438721 0.10609517 0.10609517 ... 0.04951108 0.02652379 0.04951108]
#  [0.10609517 0.10609517 0.08133963 ... 0.02652379 0.04951108 0.        ]] [0.81638463 0.80531537 0.84269623 ... 0.04951108 0.         0.03536506]

# %%
network.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])
history = network.fit(x, y, epochs=50, batch_size=125)
# Out:
# Epoch 1/50
# 1247/1247 [==============================] - 1s 900us/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 2/50
# 1247/1247 [==============================] - 0s 58us/step - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 3/50
# 1247/1247 [==============================] - 0s 67us/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 4/50
# 1247/1247 [==============================] - 0s 68us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 5/50
# 1247/1247 [==============================] - 0s 65us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 6/50
# 1247/1247 [==============================] - 0s 59us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 7/50
# 1247/1247 [==============================] - 0s 70us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 8/50
# 1247/1247 [==============================] - 0s 55us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 9/50
# 1247/1247 [==============================] - 0s 59us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 10/50
# 1247/1247 [==============================] - 0s 67us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 11/50
# 1247/1247 [==============================] - 0s 55us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 12/50
# 1247/1247 [==============================] - 0s 69us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 13/50
# 1247/1247 [==============================] - 0s 66us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 14/50
# 1247/1247 [==============================] - 0s 73us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 15/50
# 1247/1247 [==============================] - 0s 65us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 16/50
# 1247/1247 [==============================] - 0s 69us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 17/50
# 1247/1247 [==============================] - 0s 90us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 18/50
# 1247/1247 [==============================] - 0s 92us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 19/50
# 1247/1247 [==============================] - 0s 84us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 20/50
# 1247/1247 [==============================] - 0s 73us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 21/50
# 1247/1247 [==============================] - 0s 82us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 22/50
# 1247/1247 [==============================] - 0s 76us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 23/50
# 1247/1247 [==============================] - 0s 80us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 24/50
# 1247/1247 [==============================] - 0s 78us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 25/50
# 1247/1247 [==============================] - 0s 86us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 26/50
# 1247/1247 [==============================] - 0s 89us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 27/50
# 1247/1247 [==============================] - 0s 79us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 28/50
# 1247/1247 [==============================] - 0s 84us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 29/50
# 1247/1247 [==============================] - 0s 77us/step - loss: 9.8825e-04 - mean_squared_error: 9.8825e-04
# Epoch 30/50
# 1247/1247 [==============================] - 0s 77us/step - loss: 9.6470e-04 - mean_squared_error: 9.6470e-04
# Epoch 31/50
# 1247/1247 [==============================] - 0s 86us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 32/50
# 1247/1247 [==============================] - 0s 79us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 33/50
# 1247/1247 [==============================] - 0s 80us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 34/50
# 1247/1247 [==============================] - 0s 88us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 35/50
# 1247/1247 [==============================] - 0s 76us/step - loss: 9.7022e-04 - mean_squared_error: 9.7022e-04
# Epoch 36/50
# 1247/1247 [==============================] - 0s 86us/step - loss: 9.4518e-04 - mean_squared_error: 9.4518e-04
# Epoch 37/50
# 1247/1247 [==============================] - 0s 83us/step - loss: 9.5991e-04 - mean_squared_error: 9.5991e-04
# Epoch 38/50
# 1247/1247 [==============================] - 0s 85us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 39/50
# 1247/1247 [==============================] - 0s 89us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 40/50
# 1247/1247 [==============================] - 0s 83us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 41/50
# 1247/1247 [==============================] - 0s 76us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 42/50
# 1247/1247 [==============================] - 0s 81us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 43/50
# 1247/1247 [==============================] - 0s 91us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 44/50
# 1247/1247 [==============================] - 0s 80us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 45/50
# 1247/1247 [==============================] - 0s 80us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 46/50
# 1247/1247 [==============================] - 0s 77us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 47/50
# 1247/1247 [==============================] - 0s 78us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 48/50
# 1247/1247 [==============================] - 0s 69us/step - loss: 9.5320e-04 - mean_squared_error: 9.5320e-04
# Epoch 49/50
# 1247/1247 [==============================] - 0s 78us/step - loss: 9.3105e-04 - mean_squared_error: 9.3105e-04
# Epoch 50/50
# 1247/1247 [==============================] - 0s 78us/step - loss: 9.6683e-04 - mean_squared_error: 9.6683e-04

# %%
# New clean version
# orig: raw stock data, pred: predicted data
def plot(orig, pred, xstep=200, ymin=8, ymax=15, xmin=0, xmax=1500, line=-1):
    base = datetime.strptime(df.index[0], '%Y-%m-%d')
    xlabels = [(base + timedelta(days=xstep*x*7/5)).date() for x in range(0, math.ceil(xrange/xstep))]
    
    plt.figure(figsize=(8,5))
    plt.plot(np.arange(0, len(orig)), orig)
    plt.plot(np.arange(0, len(pred)), pred, lw=1)
    
    if(line != -1):
        plt.plot(line, ymin, line, ymax, color='red')
        print(line)
    
    plt.xlabel('Date')
    plt.xticks(np.arange(xmin, xmax, step=xstep), xlabels, rotation=30)
    plt.ylabel('Price')
    plt.ylim(ymin, ymax)
    plt.xlim(xmin, xmax)
    plt.title('Ford Stock Price')
    plt.show()
    plt.close()
    
# make predictions
# orig: stock data, fun: prediction function
# n: number of predictions, early: number points before end of stock data to start predicting
# returns: array of predictions
def pred(orig, fun, scaler, n=100, early=0):
    # scale orig b/t 0 and 1, and put in np array
    orig = scaler.transform(np.array(orig).reshape(len(orig),1)).reshape(len(orig))
    
    # create space for final predictions
    p = np.zeros(len(orig) + n - early)
        
    # predict before breaking away (before early off of len(orig))
    for i in range(len(orig) - 9 - early):
        p[i+11] = fun(orig[i:i+10].reshape(1,10))
        
    # predict after breaking away (after early off of len(orig))
    for i in range(len(orig) - 9 - early, len(p) - 11):
        p[i+11] = fun(p[i:i+10].reshape(1,10))
    
    return scaler.inverse_transform(p.reshape(-1,1))
    
for i in range(len(stock_full) - 200, 0, -200):
    plot(stock_full, pred(stock_full, network.predict, scaler, early=100 + i, n=200), xmin=len(stock_full) - i - 300, xmax=len(stock_full)-i + 100, line=i+100)
# Out:
# 1158
# 958
# 758
# 558
# 358
# 158

# %%
xrange = 1500
#x = np.arange(xrange)/num
# # create x: [[10 prices]...[10 prices]]
# x = [[0]*10]*(num+100)
# # stock_full = np.concatenate((stock_full, [0]*100)) # open up stock_full for extra data
# # print(stock_fuller[num:num+11])
# for i in range(num):
#     x[i] = np.array(stock_full[i:i+10]).reshape(10,1)
#     x[i] = scaler.transform(x[i])
#     x[i] = x[i].reshape(10)
# # if i >= num:
# #     stock_fuller[i+10] = scaler.inverse_transform(network.predict(np.array([x[i-1]])))
# #       print(i,stock_fuller[num-10:])
# for i in range(100):
#     y_pred = network.predict(np.array(x))

# y_pred = scaler.inverse_transform(y_pred)[:,0]
predict(data=stock_full, nw=network, scaler=scaler)

step = 200
base = datetime.strptime(df.index[0], '%Y-%m-%d')
xlabels = [(base + timedelta(days=step*x*7/5)).date() for x in range(0, math.ceil(xrange/step))]

plt.figure(figsize=(20,15))
plt.plot(np.arange(0, len(stock_full)), stock_full)
plt.plot(np.arange(0, len(y_pred))+10, y_pred, lw=1)

plt.xlabel('Date')
plt.xticks(np.arange(0, 1500, step=step), xlabels, rotation=30)
plt.ylabel('Price')
plt.ylim(8, 15)
plt.xlim(0, num+120)
# plt.xlim(num-100, num+120)
plt.title('Ford Stock Price')
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d51427f47792> in <module>()
#      24 plt.figure(figsize=(20,15))
#      25 plt.plot(np.arange(0, len(stock_full)), stock_full)
# ---> 26 plt.plot(np.arange(0, len(y_pred))+10, y_pred, lw=1)
#      27
#      28 plt.xlabel('Date')
#
# NameError: name 'y_pred' is not defined

# %%
a = np.array([[0.5, 0.0, 0.1, 0.0, 0.0, 0.4, 0.0, 0.0, 0.1, 0.0]])
print(network.predict(a))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2092e2ba9eb4> in <module>()
# ----> 1 a = np.array([[0.5, 0.0, 0.1, 0.0, 0.0, 0.4, 0.0, 0.0, 0.1, 0.0]])
#       2 print(network.predict(a))
#
# NameError: name 'np' is not defined

# %%
def predict(nw, data, scaler, offset=10, n=100):
    x = [[0]*offset]*(len(data)-offset+n)
    for i in range(len(data)-offset):
        x[i] = np.array(data[i:i+offset]).reshape(offset,1)
        x[i] = scaler.transform(x[i])
        x[i] = x[i].reshape(offset)
    y_pred = nw.predict(np.array(x))
    y_pred = scaler.inverse_transform(y_pred)[:,0]
    return y_pred
