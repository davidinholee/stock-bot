# %%
import pandas_datareader.data as web
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from keras import models, layers, optimizers
import math
from pytrends.request import TrendReq
import pytrends

# %%
stock_bot_test('F', "Ford")
# Out:
# 1158
# 1158

# %%
stock_bot_test('AAPL', "Apple", verbose=1)
# Out:
# 1157
# 1157
# Epoch 1/2000
# 1157/1157 [==============================] - 1s 526us/step - loss: 0.0750 - mean_squared_error: 0.0750
# Epoch 2/2000
# 1157/1157 [==============================] - 0s 132us/step - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 3/2000
# 1157/1157 [==============================] - 0s 130us/step - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 4/2000
# 1157/1157 [==============================] - 0s 128us/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 5/2000
# 1157/1157 [==============================] - 0s 135us/step - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 6/2000
# 1157/1157 [==============================] - 0s 130us/step - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 7/2000
# 1157/1157 [==============================] - 0s 131us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 8/2000
# 1157/1157 [==============================] - 0s 124us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 9/2000
# 1157/1157 [==============================] - 0s 128us/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 10/2000
# 1157/1157 [==============================] - 0s 125us/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 11/2000
# 1157/1157 [==============================] - 0s 136us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 12/2000
# 1157/1157 [==============================] - 0s 141us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 13/2000
# 1157/1157 [==============================] - 0s 143us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 14/2000
# 1157/1157 [==============================] - 0s 132us/step - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 15/2000
# 1157/1157 [==============================] - 0s 129us/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 16/2000
# 1157/1157 [==============================] - 0s 134us/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 17/2000
# 1157/1157 [==============================] - 0s 144us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 18/2000
# 1157/1157 [==============================] - 0s 152us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 19/2000
# 1157/1157 [==============================] - 0s 166us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 20/2000
# 1157/1157 [==============================] - 0s 175us/step - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 21/2000
# 1157/1157 [==============================] - 0s 168us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 22/2000
# 1157/1157 [==============================] - 0s 188us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 23/2000
# 1157/1157 [==============================] - 0s 143us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 24/2000
# 1157/1157 [==============================] - 0s 138us/step - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 25/2000
# 1157/1157 [==============================] - 0s 158us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 26/2000
# 1157/1157 [==============================] - 0s 144us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 27/2000
# 1157/1157 [==============================] - 0s 133us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 28/2000
# 1157/1157 [==============================] - 0s 136us/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 29/2000
# 1157/1157 [==============================] - 0s 145us/step - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 30/2000
# 1157/1157 [==============================] - 0s 143us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 31/2000
# 1157/1157 [==============================] - 0s 182us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 32/2000
# 1157/1157 [==============================] - 0s 194us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 33/2000
# 1157/1157 [==============================] - 0s 166us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 34/2000
# 1157/1157 [==============================] - 0s 144us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 35/2000
# 1157/1157 [==============================] - 0s 145us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 36/2000
# 1157/1157 [==============================] - 0s 140us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 37/2000
# 1157/1157 [==============================] - 0s 129us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 38/2000
# 1157/1157 [==============================] - 0s 138us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 39/2000
# 1157/1157 [==============================] - 0s 126us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 40/2000
# 1157/1157 [==============================] - 0s 116us/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 41/2000
# 1157/1157 [==============================] - 0s 183us/step - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 42/2000
# 1157/1157 [==============================] - 0s 177us/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 43/2000
# 1157/1157 [==============================] - 0s 184us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 44/2000
# 1157/1157 [==============================] - 0s 158us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 45/2000
# 1157/1157 [==============================] - 0s 190us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 46/2000
# 1157/1157 [==============================] - 0s 151us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 47/2000
# 1157/1157 [==============================] - 0s 141us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 48/2000
# 1157/1157 [==============================] - 0s 139us/step - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 49/2000
# 1157/1157 [==============================] - 0s 175us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 50/2000
# 1157/1157 [==============================] - 0s 149us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 51/2000
# 1157/1157 [==============================] - 0s 144us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 52/2000
# 1157/1157 [==============================] - 0s 151us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 53/2000
# 1157/1157 [==============================] - 0s 149us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 54/2000
# 1157/1157 [==============================] - 0s 138us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 55/2000
# 1157/1157 [==============================] - 0s 197us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 56/2000
# 1157/1157 [==============================] - 0s 159us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 57/2000
# 1157/1157 [==============================] - 0s 152us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 58/2000
# 1157/1157 [==============================] - 0s 173us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 59/2000
# 1157/1157 [==============================] - 0s 151us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 60/2000
# 1157/1157 [==============================] - 0s 185us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 61/2000
# 1157/1157 [==============================] - 0s 156us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 62/2000
# 1157/1157 [==============================] - 0s 155us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 63/2000
# 1157/1157 [==============================] - 0s 128us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 64/2000
# 1157/1157 [==============================] - 0s 153us/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 65/2000
# 1157/1157 [==============================] - 0s 167us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 66/2000
# 1157/1157 [==============================] - 0s 160us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 67/2000
# 1157/1157 [==============================] - 0s 132us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 68/2000
# 1157/1157 [==============================] - 0s 147us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 69/2000
# 1157/1157 [==============================] - 0s 126us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 70/2000
# 1157/1157 [==============================] - 0s 144us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 71/2000
# 1157/1157 [==============================] - 0s 137us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 72/2000
# 1157/1157 [==============================] - 0s 106us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 73/2000
# 1157/1157 [==============================] - 0s 118us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 74/2000
# 1157/1157 [==============================] - 0s 122us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 75/2000
# 1157/1157 [==============================] - 0s 146us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 76/2000
# 1157/1157 [==============================] - 0s 126us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 77/2000
# 1157/1157 [==============================] - 0s 123us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 78/2000
# 1157/1157 [==============================] - 0s 123us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 79/2000
# 1157/1157 [==============================] - 0s 123us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 80/2000
# 1157/1157 [==============================] - 0s 120us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 81/2000
# 1157/1157 [==============================] - 0s 126us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 82/2000
# 1157/1157 [==============================] - 0s 122us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 83/2000
# 1157/1157 [==============================] - 0s 123us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 84/2000
# 1157/1157 [==============================] - 0s 118us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 85/2000
# 1157/1157 [==============================] - 0s 126us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 86/2000
# 1157/1157 [==============================] - 0s 142us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 87/2000
# 1157/1157 [==============================] - 0s 158us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 88/2000
# 1157/1157 [==============================] - 0s 120us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 89/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 90/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 91/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 92/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 93/2000
# 1157/1157 [==============================] - 0s 119us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 94/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 95/2000
# 1157/1157 [==============================] - 0s 121us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 96/2000
# 1157/1157 [==============================] - 0s 108us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 97/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 98/2000
# 1157/1157 [==============================] - 0s 92us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 99/2000
# 1157/1157 [==============================] - 0s 104us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 100/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 101/2000
# 1157/1157 [==============================] - 0s 107us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 102/2000
# 1157/1157 [==============================] - 0s 92us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 103/2000
# 1157/1157 [==============================] - 0s 148us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 104/2000
# 1157/1157 [==============================] - 0s 133us/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 105/2000
# 1157/1157 [==============================] - 0s 144us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 106/2000
# 1157/1157 [==============================] - 0s 125us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 107/2000
# 1157/1157 [==============================] - 0s 151us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 108/2000
# 1157/1157 [==============================] - 0s 142us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 109/2000
# 1157/1157 [==============================] - 0s 115us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 110/2000
# 1157/1157 [==============================] - 0s 137us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 111/2000
# 1157/1157 [==============================] - 0s 145us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 112/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 113/2000
# 1157/1157 [==============================] - 0s 142us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 114/2000
# 1157/1157 [==============================] - 0s 158us/step - loss: 9.9910e-04 - mean_squared_error: 9.9910e-04
# Epoch 115/2000
# 1157/1157 [==============================] - 0s 110us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 116/2000
# 1157/1157 [==============================] - 0s 129us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 117/2000
# 1157/1157 [==============================] - 0s 154us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 118/2000
# 1157/1157 [==============================] - 0s 118us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 119/2000
# 1157/1157 [==============================] - 0s 131us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 120/2000
# 1157/1157 [==============================] - 0s 149us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 121/2000
# 1157/1157 [==============================] - 0s 141us/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 122/2000
# 1157/1157 [==============================] - 0s 113us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 123/2000
# 1157/1157 [==============================] - 0s 145us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 124/2000
# 1157/1157 [==============================] - 0s 145us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 125/2000
# 1157/1157 [==============================] - 0s 114us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 126/2000
# 1157/1157 [==============================] - 0s 148us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 127/2000
# 1157/1157 [==============================] - 0s 161us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 128/2000
# 1157/1157 [==============================] - 0s 98us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 129/2000
# 1157/1157 [==============================] - 0s 149us/step - loss: 9.7655e-04 - mean_squared_error: 9.7655e-04
# Epoch 130/2000
# 1157/1157 [==============================] - 0s 147us/step - loss: 9.9610e-04 - mean_squared_error: 9.9610e-04
# Epoch 131/2000
# 1157/1157 [==============================] - 0s 106us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 132/2000
# 1157/1157 [==============================] - 0s 147us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 133/2000
# 1157/1157 [==============================] - 0s 139us/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 134/2000
# 1157/1157 [==============================] - 0s 130us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 135/2000
# 1157/1157 [==============================] - 0s 142us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 136/2000
# 1157/1157 [==============================] - 0s 141us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 137/2000
# 1157/1157 [==============================] - 0s 171us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 138/2000
# 1157/1157 [==============================] - 0s 160us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 139/2000
# 1157/1157 [==============================] - 0s 147us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 140/2000
# 1157/1157 [==============================] - 0s 137us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 141/2000
# 1157/1157 [==============================] - 0s 141us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 142/2000
# 1157/1157 [==============================] - 0s 135us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 143/2000
# 1157/1157 [==============================] - 0s 94us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 144/2000
# 1157/1157 [==============================] - 0s 106us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 145/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 146/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 147/2000
# 1157/1157 [==============================] - 0s 120us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 148/2000
# 1157/1157 [==============================] - 0s 94us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 149/2000
# 1157/1157 [==============================] - 0s 111us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 150/2000
# 1157/1157 [==============================] - 0s 109us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 151/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 9.8538e-04 - mean_squared_error: 9.8538e-04
# Epoch 152/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 153/2000
# 1157/1157 [==============================] - 0s 104us/step - loss: 9.7670e-04 - mean_squared_error: 9.7670e-04
# Epoch 154/2000
# 1157/1157 [==============================] - 0s 95us/step - loss: 9.2442e-04 - mean_squared_error: 9.2442e-04
# Epoch 155/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 156/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 157/2000
# 1157/1157 [==============================] - 0s 99us/step - loss: 9.2469e-04 - mean_squared_error: 9.2469e-04
# Epoch 158/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 9.7620e-04 - mean_squared_error: 9.7620e-04
# Epoch 159/2000
# 1157/1157 [==============================] - 0s 108us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 160/2000
# 1157/1157 [==============================] - 0s 92us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 161/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 162/2000
# 1157/1157 [==============================] - 0s 94us/step - loss: 9.1088e-04 - mean_squared_error: 9.1088e-04
# Epoch 163/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 9.7112e-04 - mean_squared_error: 9.7112e-04
# Epoch 164/2000
# 1157/1157 [==============================] - 0s 122us/step - loss: 9.1895e-04 - mean_squared_error: 9.1895e-04
# Epoch 165/2000
# 1157/1157 [==============================] - 0s 111us/step - loss: 9.2697e-04 - mean_squared_error: 9.2697e-04
# Epoch 166/2000
# 1157/1157 [==============================] - 0s 105us/step - loss: 9.4025e-04 - mean_squared_error: 9.4025e-04
# Epoch 167/2000
# 1157/1157 [==============================] - 0s 110us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 168/2000
# 1157/1157 [==============================] - 0s 102us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 169/2000
# 1157/1157 [==============================] - 0s 98us/step - loss: 9.7487e-04 - mean_squared_error: 9.7487e-04
# Epoch 170/2000
# 1157/1157 [==============================] - 0s 103us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 171/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 9.2340e-04 - mean_squared_error: 9.2340e-04
# Epoch 172/2000
# 1157/1157 [==============================] - 0s 151us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 173/2000
# 1157/1157 [==============================] - 0s 104us/step - loss: 9.6211e-04 - mean_squared_error: 9.6211e-04
# Epoch 174/2000
# 1157/1157 [==============================] - 0s 107us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 175/2000
# 1157/1157 [==============================] - 0s 106us/step - loss: 9.9151e-04 - mean_squared_error: 9.9151e-04
# Epoch 176/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 9.5119e-04 - mean_squared_error: 9.5119e-04
# Epoch 177/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 178/2000
# 1157/1157 [==============================] - 0s 109us/step - loss: 9.7759e-04 - mean_squared_error: 9.7759e-04
# Epoch 179/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 180/2000
# 1157/1157 [==============================] - 0s 143us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 181/2000
# 1157/1157 [==============================] - 0s 156us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 182/2000
# 1157/1157 [==============================] - 0s 162us/step - loss: 9.0427e-04 - mean_squared_error: 9.0427e-04
# Epoch 183/2000
# 1157/1157 [==============================] - 0s 139us/step - loss: 8.9830e-04 - mean_squared_error: 8.9830e-04
# Epoch 184/2000
# 1157/1157 [==============================] - 0s 143us/step - loss: 9.1516e-04 - mean_squared_error: 9.1516e-04
# Epoch 185/2000
# 1157/1157 [==============================] - 0s 132us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 186/2000
# 1157/1157 [==============================] - 0s 120us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 187/2000
# 1157/1157 [==============================] - 0s 106us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 188/2000
# 1157/1157 [==============================] - 0s 95us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 189/2000
# 1157/1157 [==============================] - 0s 110us/step - loss: 9.7876e-04 - mean_squared_error: 9.7876e-04
# Epoch 190/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 191/2000
# 1157/1157 [==============================] - 0s 92us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 192/2000
# 1157/1157 [==============================] - 0s 110us/step - loss: 9.5080e-04 - mean_squared_error: 9.5080e-04
# Epoch 193/2000
# 1157/1157 [==============================] - 0s 94us/step - loss: 9.7684e-04 - mean_squared_error: 9.7684e-04
# Epoch 194/2000
# 1157/1157 [==============================] - 0s 107us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 195/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 196/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 197/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 9.3697e-04 - mean_squared_error: 9.3697e-04
# Epoch 198/2000
# 1157/1157 [==============================] - 0s 102us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 199/2000
# 1157/1157 [==============================] - 0s 87us/step - loss: 9.5986e-04 - mean_squared_error: 9.5986e-04
# Epoch 200/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 201/2000
# 1157/1157 [==============================] - 0s 107us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 202/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 203/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 9.0756e-04 - mean_squared_error: 9.0756e-04
# Epoch 204/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 9.6819e-04 - mean_squared_error: 9.6819e-04
# Epoch 205/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 206/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 9.9203e-04 - mean_squared_error: 9.9203e-04
# Epoch 207/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 208/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 9.3936e-04 - mean_squared_error: 9.3936e-04
# Epoch 209/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 210/2000
# 1157/1157 [==============================] - 0s 104us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 211/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 9.6158e-04 - mean_squared_error: 9.6158e-04
# Epoch 212/2000
# 1157/1157 [==============================] - 0s 87us/step - loss: 8.9314e-04 - mean_squared_error: 8.9314e-04
# Epoch 213/2000
# 1157/1157 [==============================] - 0s 108us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 214/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 9.5208e-04 - mean_squared_error: 9.5208e-04
# Epoch 215/2000
# 1157/1157 [==============================] - 0s 98us/step - loss: 8.8199e-04 - mean_squared_error: 8.8199e-04
# Epoch 216/2000
# 1157/1157 [==============================] - 0s 107us/step - loss: 9.5673e-04 - mean_squared_error: 9.5673e-04
# Epoch 217/2000
# 1157/1157 [==============================] - 0s 87us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 218/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 8.3992e-04 - mean_squared_error: 8.3992e-04
# Epoch 219/2000
# 1157/1157 [==============================] - 0s 103us/step - loss: 9.3178e-04 - mean_squared_error: 9.3178e-04
# Epoch 220/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 9.9911e-04 - mean_squared_error: 9.9911e-04
# Epoch 221/2000
# 1157/1157 [==============================] - 0s 94us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 222/2000
# 1157/1157 [==============================] - 0s 121us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 223/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 224/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 8.6377e-04 - mean_squared_error: 8.6377e-04
# Epoch 225/2000
# 1157/1157 [==============================] - 0s 103us/step - loss: 8.8832e-04 - mean_squared_error: 8.8832e-04
# Epoch 226/2000
# 1157/1157 [==============================] - 0s 87us/step - loss: 8.5273e-04 - mean_squared_error: 8.5273e-04
# Epoch 227/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 8.1314e-04 - mean_squared_error: 8.1314e-04
# Epoch 228/2000
# 1157/1157 [==============================] - 0s 112us/step - loss: 8.8968e-04 - mean_squared_error: 8.8968e-04
# Epoch 229/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 9.9041e-04 - mean_squared_error: 9.9041e-04
# Epoch 230/2000
# 1157/1157 [==============================] - 0s 106us/step - loss: 9.0009e-04 - mean_squared_error: 9.0009e-04
# Epoch 231/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 232/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 233/2000
# 1157/1157 [==============================] - 0s 94us/step - loss: 9.1298e-04 - mean_squared_error: 9.1298e-04
# Epoch 234/2000
# 1157/1157 [==============================] - 0s 109us/step - loss: 8.9007e-04 - mean_squared_error: 8.9007e-04
# Epoch 235/2000
# 1157/1157 [==============================] - 0s 95us/step - loss: 9.0409e-04 - mean_squared_error: 9.0409e-04
# Epoch 236/2000
# 1157/1157 [==============================] - 0s 114us/step - loss: 9.3860e-04 - mean_squared_error: 9.3860e-04
# Epoch 237/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 238/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 239/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 9.8260e-04 - mean_squared_error: 9.8260e-04
# Epoch 240/2000
# 1157/1157 [==============================] - 0s 108us/step - loss: 8.4778e-04 - mean_squared_error: 8.4778e-04
# Epoch 241/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 7.2655e-04 - mean_squared_error: 7.2655e-04
# Epoch 242/2000
# 1157/1157 [==============================] - 0s 106us/step - loss: 7.4544e-04 - mean_squared_error: 7.4544e-04
# Epoch 243/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 9.1925e-04 - mean_squared_error: 9.1925e-04
# Epoch 244/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 8.4891e-04 - mean_squared_error: 8.4891e-04
# Epoch 245/2000
# 1157/1157 [==============================] - 0s 109us/step - loss: 8.9156e-04 - mean_squared_error: 8.9156e-04
# Epoch 246/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 9.2113e-04 - mean_squared_error: 9.2113e-04
# Epoch 247/2000
# 1157/1157 [==============================] - 0s 145us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 248/2000
# 1157/1157 [==============================] - 0s 111us/step - loss: 9.3308e-04 - mean_squared_error: 9.3308e-04
# Epoch 249/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 250/2000
# 1157/1157 [==============================] - 0s 107us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 251/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 252/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 9.1404e-04 - mean_squared_error: 9.1404e-04
# Epoch 253/2000
# 1157/1157 [==============================] - 0s 104us/step - loss: 8.4337e-04 - mean_squared_error: 8.4337e-04
# Epoch 254/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 7.6989e-04 - mean_squared_error: 7.6989e-04
# Epoch 255/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 7.5085e-04 - mean_squared_error: 7.5085e-04
# Epoch 256/2000
# 1157/1157 [==============================] - 0s 109us/step - loss: 8.5449e-04 - mean_squared_error: 8.5449e-04
# Epoch 257/2000
# 1157/1157 [==============================] - 0s 105us/step - loss: 8.9910e-04 - mean_squared_error: 8.9910e-04
# Epoch 258/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 8.4263e-04 - mean_squared_error: 8.4263e-04
# Epoch 259/2000
# 1157/1157 [==============================] - 0s 102us/step - loss: 9.6008e-04 - mean_squared_error: 9.6008e-04
# Epoch 260/2000
# 1157/1157 [==============================] - 0s 125us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 261/2000
# 1157/1157 [==============================] - 0s 124us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 262/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 263/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 8.3685e-04 - mean_squared_error: 8.3685e-04
# Epoch 264/2000
# 1157/1157 [==============================] - 0s 104us/step - loss: 7.2922e-04 - mean_squared_error: 7.2922e-04
# Epoch 265/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 7.4803e-04 - mean_squared_error: 7.4803e-04
# Epoch 266/2000
# 1157/1157 [==============================] - 0s 95us/step - loss: 8.6098e-04 - mean_squared_error: 8.6098e-04
# Epoch 267/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 268/2000
# 1157/1157 [==============================] - 0s 104us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 269/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 8.5834e-04 - mean_squared_error: 8.5834e-04
# Epoch 270/2000
# 1157/1157 [==============================] - 0s 102us/step - loss: 8.5066e-04 - mean_squared_error: 8.5066e-04
# Epoch 271/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 272/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 8.3785e-04 - mean_squared_error: 8.3785e-04
# Epoch 273/2000
# 1157/1157 [==============================] - 0s 108us/step - loss: 7.3394e-04 - mean_squared_error: 7.3394e-04
# Epoch 274/2000
# 1157/1157 [==============================] - 0s 92us/step - loss: 7.5852e-04 - mean_squared_error: 7.5852e-04
# Epoch 275/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 8.0849e-04 - mean_squared_error: 8.0849e-04
# Epoch 276/2000
# 1157/1157 [==============================] - 0s 103us/step - loss: 8.2330e-04 - mean_squared_error: 8.2330e-04
# Epoch 277/2000
# 1157/1157 [==============================] - 0s 103us/step - loss: 9.6906e-04 - mean_squared_error: 9.6906e-04
# Epoch 278/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 8.6525e-04 - mean_squared_error: 8.6525e-04
# Epoch 279/2000
# 1157/1157 [==============================] - 0s 105us/step - loss: 7.4712e-04 - mean_squared_error: 7.4712e-04
# Epoch 280/2000
# 1157/1157 [==============================] - 0s 105us/step - loss: 9.1693e-04 - mean_squared_error: 9.1693e-04
# Epoch 281/2000
# 1157/1157 [==============================] - 0s 113us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 282/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 283/2000
# 1157/1157 [==============================] - 0s 104us/step - loss: 9.0108e-04 - mean_squared_error: 9.0108e-04
# Epoch 284/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 8.1228e-04 - mean_squared_error: 8.1228e-04
# Epoch 285/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 9.7883e-04 - mean_squared_error: 9.7883e-04
# Epoch 286/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 8.3692e-04 - mean_squared_error: 8.3692e-04
# Epoch 287/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 7.7589e-04 - mean_squared_error: 7.7589e-04
# Epoch 288/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 9.5153e-04 - mean_squared_error: 9.5153e-04
# Epoch 289/2000
# 1157/1157 [==============================] - 0s 92us/step - loss: 9.3533e-04 - mean_squared_error: 9.3533e-04
# Epoch 290/2000
# 1157/1157 [==============================] - 0s 132us/step - loss: 7.4607e-04 - mean_squared_error: 7.4607e-04
# Epoch 291/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 9.1843e-04 - mean_squared_error: 9.1843e-04
# Epoch 292/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 8.0448e-04 - mean_squared_error: 8.0448e-04
# Epoch 293/2000
# 1157/1157 [==============================] - 0s 106us/step - loss: 9.2037e-04 - mean_squared_error: 9.2037e-04
# Epoch 294/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 295/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 8.9736e-04 - mean_squared_error: 8.9736e-04
# Epoch 296/2000
# 1157/1157 [==============================] - 0s 98us/step - loss: 7.4026e-04 - mean_squared_error: 7.4026e-04
# Epoch 297/2000
# 1157/1157 [==============================] - 0s 92us/step - loss: 7.5740e-04 - mean_squared_error: 7.5740e-04
# Epoch 298/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 7.3947e-04 - mean_squared_error: 7.3947e-04
# Epoch 299/2000
# 1157/1157 [==============================] - 0s 103us/step - loss: 7.5563e-04 - mean_squared_error: 7.5563e-04
# Epoch 300/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 301/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 9.1598e-04 - mean_squared_error: 9.1598e-04
# Epoch 302/2000
# 1157/1157 [==============================] - 0s 116us/step - loss: 8.4901e-04 - mean_squared_error: 8.4901e-04
# Epoch 303/2000
# 1157/1157 [==============================] - 0s 104us/step - loss: 9.4848e-04 - mean_squared_error: 9.4848e-04
# Epoch 304/2000
# 1157/1157 [==============================] - 0s 105us/step - loss: 8.5592e-04 - mean_squared_error: 8.5592e-04
# Epoch 305/2000
# 1157/1157 [==============================] - 0s 114us/step - loss: 8.6073e-04 - mean_squared_error: 8.6073e-04
# Epoch 306/2000
# 1157/1157 [==============================] - 0s 107us/step - loss: 6.9637e-04 - mean_squared_error: 6.9637e-04
# Epoch 307/2000
# 1157/1157 [==============================] - 0s 109us/step - loss: 9.6499e-04 - mean_squared_error: 9.6499e-04
# Epoch 308/2000
# 1157/1157 [==============================] - 0s 103us/step - loss: 9.1718e-04 - mean_squared_error: 9.1718e-04
# Epoch 309/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 7.8972e-04 - mean_squared_error: 7.8972e-04
# Epoch 310/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 311/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 9.1829e-04 - mean_squared_error: 9.1829e-04
# Epoch 312/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 313/2000
# 1157/1157 [==============================] - 0s 112us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 314/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 7.9597e-04 - mean_squared_error: 7.9597e-04
# Epoch 315/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 7.2218e-04 - mean_squared_error: 7.2218e-04
# Epoch 316/2000
# 1157/1157 [==============================] - 0s 94us/step - loss: 7.4422e-04 - mean_squared_error: 7.4422e-04
# Epoch 317/2000
# 1157/1157 [==============================] - 0s 103us/step - loss: 6.9819e-04 - mean_squared_error: 6.9819e-04
# Epoch 318/2000
# 1157/1157 [==============================] - 0s 105us/step - loss: 6.3364e-04 - mean_squared_error: 6.3364e-04
# Epoch 319/2000
# 1157/1157 [==============================] - 0s 107us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 320/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 9.4598e-04 - mean_squared_error: 9.4598e-04
# Epoch 321/2000
# 1157/1157 [==============================] - 0s 105us/step - loss: 7.9994e-04 - mean_squared_error: 7.9994e-04
# Epoch 322/2000
# 1157/1157 [==============================] - 0s 102us/step - loss: 7.5248e-04 - mean_squared_error: 7.5248e-04
# Epoch 323/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 7.8237e-04 - mean_squared_error: 7.8237e-04
# Epoch 324/2000
# 1157/1157 [==============================] - 0s 94us/step - loss: 7.2294e-04 - mean_squared_error: 7.2294e-04
# Epoch 325/2000
# 1157/1157 [==============================] - 0s 108us/step - loss: 6.8882e-04 - mean_squared_error: 6.8882e-04
# Epoch 326/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 7.2662e-04 - mean_squared_error: 7.2662e-04
# Epoch 327/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 7.6691e-04 - mean_squared_error: 7.6691e-04
# Epoch 328/2000
# 1157/1157 [==============================] - 0s 113us/step - loss: 7.7334e-04 - mean_squared_error: 7.7334e-04
# Epoch 329/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 330/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 9.1422e-04 - mean_squared_error: 9.1422e-04
# Epoch 331/2000
# 1157/1157 [==============================] - 0s 99us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 332/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 333/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 9.6151e-04 - mean_squared_error: 9.6151e-04
# Epoch 334/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 8.0071e-04 - mean_squared_error: 8.0071e-04
# Epoch 335/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 7.1161e-04 - mean_squared_error: 7.1161e-04
# Epoch 336/2000
# 1157/1157 [==============================] - 0s 95us/step - loss: 6.5412e-04 - mean_squared_error: 6.5412e-04
# Epoch 337/2000
# 1157/1157 [==============================] - 0s 109us/step - loss: 6.7852e-04 - mean_squared_error: 6.7852e-04
# Epoch 338/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 7.7191e-04 - mean_squared_error: 7.7191e-04
# Epoch 339/2000
# 1157/1157 [==============================] - 0s 115us/step - loss: 7.4632e-04 - mean_squared_error: 7.4632e-04
# Epoch 340/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 7.0459e-04 - mean_squared_error: 7.0459e-04
# Epoch 341/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 7.0404e-04 - mean_squared_error: 7.0404e-04
# Epoch 342/2000
# 1157/1157 [==============================] - 0s 108us/step - loss: 6.3991e-04 - mean_squared_error: 6.3991e-04
# Epoch 343/2000
# 1157/1157 [==============================] - 0s 107us/step - loss: 6.1430e-04 - mean_squared_error: 6.1430e-04
# Epoch 344/2000
# 1157/1157 [==============================] - 0s 104us/step - loss: 6.0532e-04 - mean_squared_error: 6.0532e-04
# Epoch 345/2000
# 1157/1157 [==============================] - 0s 114us/step - loss: 6.4925e-04 - mean_squared_error: 6.4925e-04
# Epoch 346/2000
# 1157/1157 [==============================] - 0s 99us/step - loss: 8.1280e-04 - mean_squared_error: 8.1280e-04
# Epoch 347/2000
# 1157/1157 [==============================] - 0s 128us/step - loss: 6.7295e-04 - mean_squared_error: 6.7295e-04
# Epoch 348/2000
# 1157/1157 [==============================] - 0s 103us/step - loss: 6.7758e-04 - mean_squared_error: 6.7758e-04
# Epoch 349/2000
# 1157/1157 [==============================] - 0s 92us/step - loss: 7.0272e-04 - mean_squared_error: 7.0272e-04
# Epoch 350/2000
# 1157/1157 [==============================] - 0s 99us/step - loss: 9.6466e-04 - mean_squared_error: 9.6466e-04
# Epoch 351/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 8.8172e-04 - mean_squared_error: 8.8172e-04
# Epoch 352/2000
# 1157/1157 [==============================] - 0s 95us/step - loss: 8.8021e-04 - mean_squared_error: 8.8021e-04
# Epoch 353/2000
# 1157/1157 [==============================] - 0s 92us/step - loss: 8.0925e-04 - mean_squared_error: 8.0925e-04
# Epoch 354/2000
# 1157/1157 [==============================] - 0s 102us/step - loss: 7.2097e-04 - mean_squared_error: 7.2097e-04
# Epoch 355/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 8.1228e-04 - mean_squared_error: 8.1228e-04
# Epoch 356/2000
# 1157/1157 [==============================] - 0s 98us/step - loss: 7.2370e-04 - mean_squared_error: 7.2370e-04
# Epoch 357/2000
# 1157/1157 [==============================] - 0s 95us/step - loss: 6.8607e-04 - mean_squared_error: 6.8607e-04
# Epoch 358/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 8.7623e-04 - mean_squared_error: 8.7623e-04
# Epoch 359/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 7.9742e-04 - mean_squared_error: 7.9742e-04
# Epoch 360/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 7.2805e-04 - mean_squared_error: 7.2805e-04
# Epoch 361/2000
# 1157/1157 [==============================] - 0s 96us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 362/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 7.9416e-04 - mean_squared_error: 7.9416e-04
# Epoch 363/2000
# 1157/1157 [==============================] - 0s 101us/step - loss: 7.4635e-04 - mean_squared_error: 7.4635e-04
# Epoch 364/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 7.6770e-04 - mean_squared_error: 7.6770e-04
# Epoch 365/2000
# 1157/1157 [==============================] - 0s 92us/step - loss: 6.5238e-04 - mean_squared_error: 6.5238e-04
# Epoch 366/2000
# 1157/1157 [==============================] - 0s 102us/step - loss: 7.4211e-04 - mean_squared_error: 7.4211e-04
# Epoch 367/2000
# 1157/1157 [==============================] - 0s 103us/step - loss: 6.9489e-04 - mean_squared_error: 6.9489e-04
# Epoch 368/2000
# 1157/1157 [==============================] - 0s 108us/step - loss: 7.3302e-04 - mean_squared_error: 7.3302e-04
# Epoch 369/2000
# 1157/1157 [==============================] - 0s 102us/step - loss: 6.5110e-04 - mean_squared_error: 6.5110e-04
# Epoch 370/2000
# 1157/1157 [==============================] - 0s 92us/step - loss: 7.4748e-04 - mean_squared_error: 7.4748e-04
# Epoch 371/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 6.2498e-04 - mean_squared_error: 6.2498e-04
# Epoch 372/2000
# 1157/1157 [==============================] - 0s 100us/step - loss: 6.2065e-04 - mean_squared_error: 6.2065e-04
# Epoch 373/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 6.5615e-04 - mean_squared_error: 6.5615e-04
# Epoch 374/2000
# 1157/1157 [==============================] - 0s 118us/step - loss: 6.0019e-04 - mean_squared_error: 6.0019e-04
# Epoch 375/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 6.0641e-04 - mean_squared_error: 6.0641e-04
# Epoch 376/2000
# 1157/1157 [==============================] - 0s 106us/step - loss: 6.7238e-04 - mean_squared_error: 6.7238e-04
# Epoch 377/2000
# 1157/1157 [==============================] - 0s 110us/step - loss: 8.1172e-04 - mean_squared_error: 8.1172e-04
# Epoch 378/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 7.3577e-04 - mean_squared_error: 7.3577e-04
# Epoch 379/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 6.5009e-04 - mean_squared_error: 6.5009e-04
# Epoch 380/2000
# 1157/1157 [==============================] - 0s 95us/step - loss: 7.4985e-04 - mean_squared_error: 7.4985e-04
# Epoch 381/2000
# 1157/1157 [==============================] - 0s 97us/step - loss: 8.1875e-04 - mean_squared_error: 8.1875e-04
# Epoch 382/2000
# 1157/1157 [==============================] - 0s 102us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 383/2000
# 1157/1157 [==============================] - 0s 115us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 384/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 385/2000
# 1157/1157 [==============================] - 0s 114us/step - loss: 7.8431e-04 - mean_squared_error: 7.8431e-04
# Epoch 386/2000
# 1157/1157 [==============================] - 0s 90us/step - loss: 6.4831e-04 - mean_squared_error: 6.4831e-04
# Epoch 387/2000
# 1157/1157 [==============================] - 0s 114us/step - loss: 6.6754e-04 - mean_squared_error: 6.6754e-04
# Epoch 388/2000
# 1157/1157 [==============================] - 0s 108us/step - loss: 7.0098e-04 - mean_squared_error: 7.0098e-04
# Epoch 389/2000
# 1157/1157 [==============================] - 0s 111us/step - loss: 6.7847e-04 - mean_squared_error: 6.7847e-04
# Epoch 390/2000
# 1157/1157 [==============================] - 0s 89us/step - loss: 7.7626e-04 - mean_squared_error: 7.7626e-04
# Epoch 391/2000
# 1157/1157 [==============================] - 0s 102us/step - loss: 8.5668e-04 - mean_squared_error: 8.5668e-04
# Epoch 392/2000
# 1157/1157 [==============================] - 0s 88us/step - loss: 8.4982e-04 - mean_squared_error: 8.4982e-04
# Epoch 393/2000
# 1157/1157 [==============================] - 0s 93us/step - loss: 6.8906e-04 - mean_squared_error: 6.8906e-04
# Epoch 394/2000
# 1157/1157 [==============================] - 0s 108us/step - loss: 5.9056e-04 - mean_squared_error: 5.9056e-04
# Epoch 395/2000
# 1157/1157 [==============================] - 0s 91us/step - loss: 6.0991e-04 - mean_squared_error: 6.0991e-04
# Epoch 396/2000
# 1157/1157 [==============================] - 0s 94us/step - loss: 7.4009e-04 - mean_squared_error: 7.4009e-04
# Epoch 397/2000
# ...
# 1157/1157 [==============================] - 0s 128us/step - loss: 4.0030e-04 - mean_squared_error: 4.0030e-04
# Epoch 1876/2000
# 1157/1157 [==============================] - 0s 135us/step - loss: 4.6274e-04 - mean_squared_error: 4.6274e-04
# Epoch 1877/2000
# 1157/1157 [==============================] - 0s 128us/step - loss: 5.0900e-04 - mean_squared_error: 5.0900e-04
# Epoch 1878/2000
# 1157/1157 [==============================] - 0s 134us/step - loss: 3.8600e-04 - mean_squared_error: 3.8600e-04
# Epoch 1879/2000
# 1157/1157 [==============================] - 0s 130us/step - loss: 3.2908e-04 - mean_squared_error: 3.2908e-04
# Epoch 1880/2000
# 1157/1157 [==============================] - 0s 151us/step - loss: 3.2028e-04 - mean_squared_error: 3.2028e-04
# Epoch 1881/2000
# 1157/1157 [==============================] - 0s 129us/step - loss: 3.0370e-04 - mean_squared_error: 3.0370e-04
# Epoch 1882/2000
# 1157/1157 [==============================] - 0s 158us/step - loss: 2.6657e-04 - mean_squared_error: 2.6657e-04
# Epoch 1883/2000
# 1157/1157 [==============================] - 0s 124us/step - loss: 3.0172e-04 - mean_squared_error: 3.0172e-04
# Epoch 1884/2000
# 1157/1157 [==============================] - 0s 125us/step - loss: 3.0133e-04 - mean_squared_error: 3.0133e-04
# Epoch 1885/2000
# 1157/1157 [==============================] - 0s 138us/step - loss: 2.5189e-04 - mean_squared_error: 2.5189e-04
# Epoch 1886/2000
# 1157/1157 [==============================] - 0s 131us/step - loss: 3.1909e-04 - mean_squared_error: 3.1909e-04
# Epoch 1887/2000
# 1157/1157 [==============================] - 0s 131us/step - loss: 3.0388e-04 - mean_squared_error: 3.0388e-04
# Epoch 1888/2000
# 1157/1157 [==============================] - 0s 133us/step - loss: 3.0965e-04 - mean_squared_error: 3.0965e-04
# Epoch 1889/2000
# 1157/1157 [==============================] - 0s 121us/step - loss: 2.8975e-04 - mean_squared_error: 2.8975e-04
# Epoch 1890/2000
# 1157/1157 [==============================] - 0s 107us/step - loss: 3.3716e-04 - mean_squared_error: 3.3716e-04
# Epoch 1891/2000
# 1157/1157 [==============================] - 0s 115us/step - loss: 3.2101e-04 - mean_squared_error: 3.2101e-04
# Epoch 1892/2000
# 1157/1157 [==============================] - 0s 124us/step - loss: 3.0988e-04 - mean_squared_error: 3.0988e-04
# Epoch 1893/2000
# 1157/1157 [==============================] - 0s 116us/step - loss: 4.0758e-04 - mean_squared_error: 4.0758e-04
# Epoch 1894/2000
# 1157/1157 [==============================] - 0s 126us/step - loss: 3.1031e-04 - mean_squared_error: 3.1031e-04
# Epoch 1895/2000
# 1157/1157 [==============================] - 0s 116us/step - loss: 3.3007e-04 - mean_squared_error: 3.3007e-04
# Epoch 1896/2000
# 1157/1157 [==============================] - 0s 125us/step - loss: 2.9519e-04 - mean_squared_error: 2.9519e-04
# Epoch 1897/2000
# 1157/1157 [==============================] - 0s 109us/step - loss: 3.1833e-04 - mean_squared_error: 3.1833e-04
# Epoch 1898/2000
# 1157/1157 [==============================] - 0s 112us/step - loss: 2.9142e-04 - mean_squared_error: 2.9142e-04
# Epoch 1899/2000
# 1157/1157 [==============================] - 0s 128us/step - loss: 3.4035e-04 - mean_squared_error: 3.4035e-04
# Epoch 1900/2000
# 1157/1157 [==============================] - 0s 118us/step - loss: 3.5616e-04 - mean_squared_error: 3.5616e-04
# Epoch 1901/2000
# 1157/1157 [==============================] - 0s 128us/step - loss: 3.1511e-04 - mean_squared_error: 3.1511e-04
# Epoch 1902/2000
# 1157/1157 [==============================] - 0s 108us/step - loss: 3.0459e-04 - mean_squared_error: 3.0459e-04
# Epoch 1903/2000
# 1157/1157 [==============================] - 0s 135us/step - loss: 2.5460e-04 - mean_squared_error: 2.5460e-04
# Epoch 1904/2000
# 1157/1157 [==============================] - 0s 126us/step - loss: 3.3895e-04 - mean_squared_error: 3.3895e-04
# Epoch 1905/2000
# 1157/1157 [==============================] - 0s 112us/step - loss: 2.3411e-04 - mean_squared_error: 2.3411e-04
# Epoch 1906/2000
# 1157/1157 [==============================] - 0s 136us/step - loss: 3.0717e-04 - mean_squared_error: 3.0717e-04
# Epoch 1907/2000
# 1157/1157 [==============================] - 0s 118us/step - loss: 2.7274e-04 - mean_squared_error: 2.7274e-04
# Epoch 1908/2000
# 1157/1157 [==============================] - 0s 127us/step - loss: 2.7615e-04 - mean_squared_error: 2.7615e-04
# Epoch 1909/2000
# 1157/1157 [==============================] - 0s 120us/step - loss: 3.2360e-04 - mean_squared_error: 3.2360e-04
# Epoch 1910/2000
# 1157/1157 [==============================] - 0s 135us/step - loss: 4.2739e-04 - mean_squared_error: 4.2739e-04
# Epoch 1911/2000
# 1157/1157 [==============================] - 0s 155us/step - loss: 4.6754e-04 - mean_squared_error: 4.6754e-04
# Epoch 1912/2000
# 1157/1157 [==============================] - 0s 171us/step - loss: 3.4847e-04 - mean_squared_error: 3.4847e-04
# Epoch 1913/2000
# 1157/1157 [==============================] - 0s 136us/step - loss: 2.7286e-04 - mean_squared_error: 2.7286e-04
# Epoch 1914/2000
# 1157/1157 [==============================] - 0s 144us/step - loss: 2.7312e-04 - mean_squared_error: 2.7312e-04
# Epoch 1915/2000
# 1157/1157 [==============================] - 0s 132us/step - loss: 2.9918e-04 - mean_squared_error: 2.9918e-04
# Epoch 1916/2000
# 1157/1157 [==============================] - 0s 152us/step - loss: 4.3923e-04 - mean_squared_error: 4.3923e-04
# Epoch 1917/2000
# 1157/1157 [==============================] - 0s 134us/step - loss: 2.8096e-04 - mean_squared_error: 2.8096e-04
# Epoch 1918/2000
# 1157/1157 [==============================] - 0s 142us/step - loss: 3.6702e-04 - mean_squared_error: 3.6702e-04
# Epoch 1919/2000
# 1157/1157 [==============================] - 0s 126us/step - loss: 5.1244e-04 - mean_squared_error: 5.1244e-04
# Epoch 1920/2000
# 1157/1157 [==============================] - 0s 153us/step - loss: 4.1629e-04 - mean_squared_error: 4.1629e-04
# Epoch 1921/2000
# 1157/1157 [==============================] - 0s 129us/step - loss: 2.9047e-04 - mean_squared_error: 2.9047e-04
# Epoch 1922/2000
# 1157/1157 [==============================] - 0s 142us/step - loss: 3.3860e-04 - mean_squared_error: 3.3860e-04
# Epoch 1923/2000
# 1157/1157 [==============================] - 0s 133us/step - loss: 3.5534e-04 - mean_squared_error: 3.5534e-04
# Epoch 1924/2000
# 1157/1157 [==============================] - 0s 172us/step - loss: 2.8042e-04 - mean_squared_error: 2.8042e-04
# Epoch 1925/2000
# 1157/1157 [==============================] - 0s 130us/step - loss: 3.2926e-04 - mean_squared_error: 3.2926e-04
# Epoch 1926/2000
# 1157/1157 [==============================] - 0s 132us/step - loss: 4.4747e-04 - mean_squared_error: 4.4747e-04
# Epoch 1927/2000
# 1157/1157 [==============================] - 0s 135us/step - loss: 4.1480e-04 - mean_squared_error: 4.1480e-04
# Epoch 1928/2000
# 1157/1157 [==============================] - 0s 139us/step - loss: 4.9776e-04 - mean_squared_error: 4.9776e-04
# Epoch 1929/2000
# 1157/1157 [==============================] - 0s 131us/step - loss: 5.0325e-04 - mean_squared_error: 5.0325e-04
# Epoch 1930/2000
# 1157/1157 [==============================] - 0s 131us/step - loss: 3.1122e-04 - mean_squared_error: 3.1122e-04
# Epoch 1931/2000
# 1157/1157 [==============================] - 0s 154us/step - loss: 3.0175e-04 - mean_squared_error: 3.0175e-04
# Epoch 1932/2000
# 1157/1157 [==============================] - 0s 126us/step - loss: 2.7343e-04 - mean_squared_error: 2.7343e-04
# Epoch 1933/2000
# 1157/1157 [==============================] - 0s 131us/step - loss: 2.7883e-04 - mean_squared_error: 2.7883e-04
# Epoch 1934/2000
# 1157/1157 [==============================] - 0s 143us/step - loss: 2.9127e-04 - mean_squared_error: 2.9127e-04
# Epoch 1935/2000
# 1157/1157 [==============================] - 0s 122us/step - loss: 2.5918e-04 - mean_squared_error: 2.5918e-04
# Epoch 1936/2000
# 1157/1157 [==============================] - 0s 117us/step - loss: 3.2351e-04 - mean_squared_error: 3.2351e-04
# Epoch 1937/2000
# 1157/1157 [==============================] - 0s 132us/step - loss: 3.2561e-04 - mean_squared_error: 3.2561e-04
# Epoch 1938/2000
# 1157/1157 [==============================] - 0s 123us/step - loss: 2.4165e-04 - mean_squared_error: 2.4165e-04
# Epoch 1939/2000
# 1157/1157 [==============================] - 0s 124us/step - loss: 2.5695e-04 - mean_squared_error: 2.5695e-04
# Epoch 1940/2000
# 1157/1157 [==============================] - 0s 120us/step - loss: 2.4019e-04 - mean_squared_error: 2.4019e-04
# Epoch 1941/2000
# 1157/1157 [==============================] - 0s 130us/step - loss: 2.3822e-04 - mean_squared_error: 2.3822e-04
# Epoch 1942/2000
# 1157/1157 [==============================] - 0s 123us/step - loss: 2.8726e-04 - mean_squared_error: 2.8726e-04
# Epoch 1943/2000
# 1157/1157 [==============================] - 0s 116us/step - loss: 3.8051e-04 - mean_squared_error: 3.8051e-04
# Epoch 1944/2000
# 1157/1157 [==============================] - 0s 133us/step - loss: 4.0099e-04 - mean_squared_error: 4.0099e-04
# Epoch 1945/2000
# 1157/1157 [==============================] - 0s 137us/step - loss: 2.9366e-04 - mean_squared_error: 2.9366e-04
# Epoch 1946/2000
# 1157/1157 [==============================] - 0s 145us/step - loss: 2.9450e-04 - mean_squared_error: 2.9450e-04
# Epoch 1947/2000
# 1157/1157 [==============================] - 0s 123us/step - loss: 2.9310e-04 - mean_squared_error: 2.9310e-04
# Epoch 1948/2000
# 1157/1157 [==============================] - 0s 128us/step - loss: 3.0523e-04 - mean_squared_error: 3.0523e-04
# Epoch 1949/2000
# 1157/1157 [==============================] - 0s 140us/step - loss: 3.1019e-04 - mean_squared_error: 3.1019e-04
# Epoch 1950/2000
# 1157/1157 [==============================] - 0s 118us/step - loss: 3.0617e-04 - mean_squared_error: 3.0617e-04
# Epoch 1951/2000
# 1157/1157 [==============================] - 0s 129us/step - loss: 2.5926e-04 - mean_squared_error: 2.5926e-04
# Epoch 1952/2000
# 1157/1157 [==============================] - 0s 117us/step - loss: 3.8896e-04 - mean_squared_error: 3.8896e-04
# Epoch 1953/2000
# 1157/1157 [==============================] - 0s 123us/step - loss: 3.4791e-04 - mean_squared_error: 3.4791e-04
# Epoch 1954/2000
# 1157/1157 [==============================] - 0s 112us/step - loss: 2.8049e-04 - mean_squared_error: 2.8049e-04
# Epoch 1955/2000
# 1157/1157 [==============================] - 0s 128us/step - loss: 2.6140e-04 - mean_squared_error: 2.6140e-04
# Epoch 1956/2000
# 1157/1157 [==============================] - 0s 118us/step - loss: 2.4649e-04 - mean_squared_error: 2.4649e-04
# Epoch 1957/2000
# 1157/1157 [==============================] - 0s 128us/step - loss: 3.0151e-04 - mean_squared_error: 3.0151e-04
# Epoch 1958/2000
# 1157/1157 [==============================] - 0s 135us/step - loss: 5.4137e-04 - mean_squared_error: 5.4137e-04
# Epoch 1959/2000
# 1157/1157 [==============================] - 0s 120us/step - loss: 5.7706e-04 - mean_squared_error: 5.7706e-04
# Epoch 1960/2000
# 1157/1157 [==============================] - 0s 127us/step - loss: 3.3692e-04 - mean_squared_error: 3.3692e-04
# Epoch 1961/2000
# 1157/1157 [==============================] - 0s 114us/step - loss: 3.2503e-04 - mean_squared_error: 3.2503e-04
# Epoch 1962/2000
# 1157/1157 [==============================] - 0s 122us/step - loss: 2.6216e-04 - mean_squared_error: 2.6216e-04
# Epoch 1963/2000
# 1157/1157 [==============================] - 0s 113us/step - loss: 2.7152e-04 - mean_squared_error: 2.7152e-04
# Epoch 1964/2000
# 1157/1157 [==============================] - 0s 124us/step - loss: 3.9774e-04 - mean_squared_error: 3.9774e-04
# Epoch 1965/2000
# 1157/1157 [==============================] - 0s 124us/step - loss: 2.8925e-04 - mean_squared_error: 2.8925e-04
# Epoch 1966/2000
# 1157/1157 [==============================] - 0s 112us/step - loss: 2.8023e-04 - mean_squared_error: 2.8023e-04
# Epoch 1967/2000
# 1157/1157 [==============================] - 0s 128us/step - loss: 2.5470e-04 - mean_squared_error: 2.5470e-04
# Epoch 1968/2000
# 1157/1157 [==============================] - 0s 119us/step - loss: 2.8266e-04 - mean_squared_error: 2.8266e-04
# Epoch 1969/2000
# 1157/1157 [==============================] - 0s 121us/step - loss: 2.7265e-04 - mean_squared_error: 2.7265e-04
# Epoch 1970/2000
# 1157/1157 [==============================] - 0s 118us/step - loss: 3.1399e-04 - mean_squared_error: 3.1399e-04
# Epoch 1971/2000
# 1157/1157 [==============================] - 0s 117us/step - loss: 3.8506e-04 - mean_squared_error: 3.8506e-04
# Epoch 1972/2000
# 1157/1157 [==============================] - 0s 135us/step - loss: 3.5602e-04 - mean_squared_error: 3.5602e-04
# Epoch 1973/2000
# 1157/1157 [==============================] - 0s 123us/step - loss: 2.6767e-04 - mean_squared_error: 2.6767e-04
# Epoch 1974/2000
# 1157/1157 [==============================] - 0s 127us/step - loss: 3.1748e-04 - mean_squared_error: 3.1748e-04
# Epoch 1975/2000
# 1157/1157 [==============================] - 0s 125us/step - loss: 3.3017e-04 - mean_squared_error: 3.3017e-04
# Epoch 1976/2000
# 1157/1157 [==============================] - 0s 127us/step - loss: 3.7964e-04 - mean_squared_error: 3.7964e-04
# Epoch 1977/2000
# 1157/1157 [==============================] - 0s 145us/step - loss: 2.7636e-04 - mean_squared_error: 2.7636e-04
# Epoch 1978/2000
# 1157/1157 [==============================] - 0s 119us/step - loss: 3.2392e-04 - mean_squared_error: 3.2392e-04
# Epoch 1979/2000
# 1157/1157 [==============================] - 0s 130us/step - loss: 3.4607e-04 - mean_squared_error: 3.4607e-04
# Epoch 1980/2000
# 1157/1157 [==============================] - 0s 124us/step - loss: 2.9188e-04 - mean_squared_error: 2.9188e-04
# Epoch 1981/2000
# 1157/1157 [==============================] - 0s 140us/step - loss: 2.5561e-04 - mean_squared_error: 2.5561e-04
# Epoch 1982/2000
# 1157/1157 [==============================] - 0s 133us/step - loss: 3.1081e-04 - mean_squared_error: 3.1081e-04
# Epoch 1983/2000
# 1157/1157 [==============================] - 0s 123us/step - loss: 2.6690e-04 - mean_squared_error: 2.6690e-04
# Epoch 1984/2000
# 1157/1157 [==============================] - 0s 124us/step - loss: 2.5348e-04 - mean_squared_error: 2.5348e-04
# Epoch 1985/2000
# 1157/1157 [==============================] - 0s 126us/step - loss: 2.8220e-04 - mean_squared_error: 2.8220e-04
# Epoch 1986/2000
# 1157/1157 [==============================] - 0s 111us/step - loss: 3.2313e-04 - mean_squared_error: 3.2313e-04
# Epoch 1987/2000
# 1157/1157 [==============================] - 0s 136us/step - loss: 4.0556e-04 - mean_squared_error: 4.0556e-04
# Epoch 1988/2000
# 1157/1157 [==============================] - 0s 124us/step - loss: 3.4706e-04 - mean_squared_error: 3.4706e-04
# Epoch 1989/2000
# 1157/1157 [==============================] - 0s 139us/step - loss: 3.5443e-04 - mean_squared_error: 3.5443e-04
# Epoch 1990/2000
# 1157/1157 [==============================] - 0s 141us/step - loss: 3.1697e-04 - mean_squared_error: 3.1697e-04
# Epoch 1991/2000
# 1157/1157 [==============================] - 0s 127us/step - loss: 4.4575e-04 - mean_squared_error: 4.4575e-04
# Epoch 1992/2000
# 1157/1157 [==============================] - 0s 138us/step - loss: 3.4703e-04 - mean_squared_error: 3.4703e-04
# Epoch 1993/2000
# 1157/1157 [==============================] - 0s 120us/step - loss: 3.7064e-04 - mean_squared_error: 3.7064e-04
# Epoch 1994/2000
# 1157/1157 [==============================] - 0s 132us/step - loss: 3.2711e-04 - mean_squared_error: 3.2711e-04
# Epoch 1995/2000
# 1157/1157 [==============================] - 0s 135us/step - loss: 2.6621e-04 - mean_squared_error: 2.6621e-04
# Epoch 1996/2000
# 1157/1157 [==============================] - 0s 137us/step - loss: 2.9636e-04 - mean_squared_error: 2.9636e-04
# Epoch 1997/2000
# 1157/1157 [==============================] - 0s 134us/step - loss: 2.3185e-04 - mean_squared_error: 2.3185e-04
# Epoch 1998/2000
# 1157/1157 [==============================] - 0s 153us/step - loss: 2.3115e-04 - mean_squared_error: 2.3115e-04
# Epoch 1999/2000
# 1157/1157 [==============================] - 0s 138us/step - loss: 2.3826e-04 - mean_squared_error: 2.3826e-04
# Epoch 2000/2000
# 1157/1157 [==============================] - 0s 137us/step - loss: 2.4190e-04 - mean_squared_error: 2.4190e-04

# %%
stock_bot_test('WMT', "Walmart")
# Out:
# 1158
# 1158

# %%
# Doesn't generate images
def stock_bot_test(stock_name, comp_name, verbose=0):
    # ---- Read stock data and Google trends data.
    start = datetime.today() - timedelta(370*5)
    end = datetime.today() - timedelta(1)
    df = web.DataReader(stock_name, 'iex', start, end)
    stock = df.loc[:,'open']
    num = len(stock) - 101
    print(num)
    
    pytrends = TrendReq(hl='en-US', tz=300)
    frame = df.index[0] + ' ' + df.index[-101]
    pytrends.build_payload([comp_name], timeframe=frame, cat=0, geo='US')
    search = pytrends.interest_over_time()
    
    # ---- Rescale trends data to be between -.5 and .5
    trend_max = max(search.values[:,0])
    trend_min = min(search.values[:,0])
    trend_range = trend_max - trend_min
    trend_med = trend_min + (trend_range / 2)
    search_scaled = np.zeros((len(search.values)))
    search_scaled = (search.values[:, 0] - trend_med) / trend_range
    
    # ---- Format input features as (day, trend value)
    x = np.zeros((num, 2))
    ind_cur = 0
    trend_cur = search_scaled[ind_cur]
    for i in range(len(x)):
        x[i, 0] = (i / num) - .7
        if (ind_cur < len(search_scaled) and search.index[ind_cur].year == int(df.index[i][:4]) and search.index[ind_cur].month == int(df.index[i][5:7]) and search.index[ind_cur].day <= int(df.index[i][8:])+2 and search.index[ind_cur].day >= int(df.index[i][8:])-2):
            trend_cur = search_scaled[ind_cur]
            ind_cur += 1
        x[i, 1] = trend_cur
    
    # ---- Normalize stock data
    y = stock[:-101]
    scaler = MinMaxScaler()
    y = np.array(stock[:-101]).reshape(len(stock[:-101]), 1)
    scaler = scaler.fit(y)
    y = scaler.transform(y)
    y = y.reshape(len(stock[:-101]))
    print(len(y))
    
    # ---- Shuffle data
    shuffle_indices = np.random.permutation(np.arange(len(y)))
    y = y[shuffle_indices]
    x = x[shuffle_indices]
    
    # ---- Construct network
    network = models.Sequential()
    network.add(layers.Dense(256, activation='relu', input_shape=(2,)))
    network.add(layers.Dense(256, activation='relu'))
    network.add(layers.Dense(256, activation='relu'))
    network.add(layers.Dense(128, activation='relu'))
    network.add(layers.Dense(128, activation='relu'))
    network.add(layers.Dense(128, activation='relu'))
    network.add(layers.Dense(64, activation='relu'))
    network.add(layers.Dense(64, activation='relu'))
    network.add(layers.Dense(64, activation='relu'))
    network.add(layers.Dense(1))
    
    # ---- Compile and run network
    network.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])
    history = network.fit(x, y, epochs=2000, batch_size=50, verbose=verbose)
    
    # ---- Build test data set
    xrange = 1400
    x_test = np.zeros((xrange, 2))
    ind_cur = 0
    trend_cur = search_scaled[ind_cur]
    for i in range(len(x_test)):
        x_test[i, 0] = (i / num) - .7
        if (ind_cur < len(search_scaled) and search.index[ind_cur].year == int(df.index[i][:4]) and search.index[ind_cur].month == int(df.index[i][5:7]) and search.index[ind_cur].day <= int(df.index[i][8:])+2 and search.index[ind_cur].day >= int(df.index[i][8:])-2):
            trend_cur = search_scaled[ind_cur]
            ind_cur += 1
        x_test[i, 1] = trend_cur
    y_pred = network.predict(x_test)
    y_pred = scaler.inverse_transform(y_pred)[:,0]
    
    num = len(stock)
    
    # ---- Plot the predicted data
    step = 200
    base = datetime.strptime(df.index[0], '%Y-%m-%d')
    xlabels = [(base + timedelta(days=step*x_test*7/5)).date() for x_test in range(0, math.ceil(xrange/step))]
    
    plt.figure(figsize=(10,7))
    plt.plot(np.arange(0, num), stock)
    plt.plot(np.arange(0, xrange), y_pred, lw=3)
    plt.axvline(x=num-101)

    plt.xlabel('Date')
    plt.xticks(np.arange(0, 1400, step=step), xlabels, rotation=30)
    plt.ylabel('Price')
    plt.title(comp_name + ' Stock Price')
    plt.savefig('figures/' + comp_name + '_pred' + '.png')
    plt.show()
    plt.close()

# %%
# Does't generate images
def stock_bot(stock_name, comp_name):
    # ---- Read stock data and Google trends data.
    start = datetime.today() - timedelta(370*5)
    end = datetime.today() - timedelta(1)
    df = web.DataReader(stock_name, 'iex', start, end)
    stock = df.loc[:,'open']
    num = len(stock)
    print(num)
    
    pytrends = TrendReq(hl='en-US', tz=300)
    frame = df.index[0] + ' ' + df.index[-1]
    pytrends.build_payload([comp_name], timeframe=frame, cat=0, geo='US')
    search = pytrends.interest_over_time()
    
    # ---- Rescale trends data to be between -.5 and .5
    trend_max = max(search.values[:,0])
    trend_min = min(search.values[:,0])
    trend_range = trend_max - trend_min
    trend_med = trend_min + (trend_range / 2)
    search_scaled = np.zeros((len(search.values)))
    search_scaled = (search.values[:, 0] - trend_med) / trend_range
    
    # ---- Format input features as (day, trend value)
    x = np.zeros((num, 2))
    ind_cur = 0
    trend_cur = search_scaled[ind_cur]
    for i in range(len(x)):
        x[i, 0] = (i / num) - .7
        if (ind_cur < len(search_scaled) and search.index[ind_cur].year == int(df.index[i][:4]) and search.index[ind_cur].month == int(df.index[i][5:7]) and search.index[ind_cur].day <= int(df.index[i][8:])+2 and search.index[ind_cur].day >= int(df.index[i][8:])-2):
            trend_cur = search_scaled[ind_cur]
            ind_cur += 1
        x[i, 1] = trend_cur
    
    # ---- Normalize stock data
    y = stock
    scaler = MinMaxScaler()
    y = np.array(stock).reshape(len(stock), 1)
    scaler = scaler.fit(y)
    y = scaler.transform(y)
    y = y.reshape(len(stock))
    
    # ---- Shuffle data
    shuffle_indices = np.random.permutation(np.arange(len(y)))
    y = y[shuffle_indices]
    x = x[shuffle_indices]
    
    # ---- Construct network
    network = models.Sequential()
    network.add(layers.Dense(256, activation='relu', input_shape=(2,)))
    network.add(layers.Dense(256, activation='relu'))
    network.add(layers.Dense(256, activation='relu'))
    network.add(layers.Dense(128, activation='relu'))
    network.add(layers.Dense(128, activation='relu'))
    network.add(layers.Dense(128, activation='relu'))
    network.add(layers.Dense(64, activation='relu'))
    network.add(layers.Dense(64, activation='relu'))
    network.add(layers.Dense(64, activation='relu'))
    network.add(layers.Dense(1))
    
    # ---- Compile and run network
    network.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])
    history = network.fit(x, y, epochs=2000, batch_size=50, verbose=1)
    
    # ---- Build test data set
    xrange = 1259
    x_test = np.zeros((xrange, 2))
    ind_cur = 0
    trend_cur = search_scaled[ind_cur]
    for i in range(len(x_test)):
        x_test[i, 0] = (i / num) - .7
        if (ind_cur < len(search_scaled) and search.index[ind_cur].year == int(df.index[i][:4]) and search.index[ind_cur].month == int(df.index[i][5:7]) and search.index[ind_cur].day <= int(df.index[i][8:])+2 and search.index[ind_cur].day >= int(df.index[i][8:])-2):
            trend_cur = search_scaled[ind_cur]
            ind_cur += 1
        x_test[i, 1] = trend_cur
    y_pred = network.predict(x_test)
    y_pred = scaler.inverse_transform(y_pred)[:,0]
    
    # ---- Plot the predicted data
    step = 200
    base = datetime.strptime(df.index[0], '%Y-%m-%d')
    xlabels = [(base + timedelta(days=step*x_test*7/5)).date() for x_test in range(0, math.ceil(xrange/step))]
    
    plt.figure(figsize=(10,7))
    plt.plot(np.arange(0, num), stock)
    plt.plot(np.arange(0, xrange), y_pred, lw=3)

    plt.xlabel('Date')
    plt.xticks(np.arange(0, 1400, step=step), xlabels, rotation=30)
    plt.ylabel('Price')
    plt.title(comp_name + ' Stock Price')
    plt.savefig('figures/' + comp_name + '_pred' + '.png')
    plt.show()
    plt.close()

# %%
# Checks prediction function against actual data
# Simplest version of checking -- not super accurate
def simple_check(pred_fun, real_data):
    gen_data = []
    for i in range(len(real_data)):
        gen_data.append(pred_fun(i))
    gen_mat = np.array(gen_data)
    real_mat = np.array(real_data)
    return np.average(gen_mat - real_mat)

# %%
def fun(i):
    return i+5
simple_check(fun, [3,4,5])
# Out:
# 2.0
